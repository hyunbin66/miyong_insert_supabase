# %%
# !pip install pandas openpyxl

# %%
# !pip install supabase

# %%
import pandas as pd
import glob
import os
from supabase import create_client, Client
from dotenv import load_dotenv

# %%
# .env 파일 로드
load_dotenv()

# Supabase API 정보 입력 (자신의 Supabase 프로젝트 URL과 API 키로 대체)
url = 'https://aqwfljjtpddgqznegtfu.supabase.co'  # Supabase API URL
key = os.getenv('SUPABASE_API_KEY')
# Supabase 클라이언트 생성
supabase: Client = create_client(url, key)

print(key)
# Out:
# eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpc3MiOiJzdXBhYmFzZSIsInJlZiI6ImFxd2Zsamp0cGRkZ3F6bmVndGZ1Iiwicm9sZSI6InNlcnZpY2Vfcm9sZSIsImlhdCI6MTcyNTUwNTAxNSwiZXhwIjoyMDQxMDgxMDE1fQ.C-rifI7V5uk1ejO61vmNe4e9xzoEsStPrBrL9cGzh9E

# %%
license = '미용사(피부)'
license_id = ''

response = supabase.table('licenses').select('id').eq('license', license).execute()

# id 값 추출
if response.data:
    license_id = response.data[0]['id']  # 첫 번째 row의 'id'를 사용
    print(f"License ID: {license_id}")
else:
    raise ValueError(f"No license found with name '{license}'")
# Out:
# License ID: 2

# %%
folder_path = f'{license}'
file_paths = glob.glob(os.path.join(folder_path, "*.xlsx"))

# 파일들을 저장할 데이터프레임 리스트
questions_df_list = []

count = 1

# 각 파일을 읽어서 데이터프레임으로 변환 후 리스트에 추가
for file in file_paths:
    df = pd.read_excel(file, header=0)
    print(f'{count} : {df.columns}')
    count +=1
# Out:
# 1 : Index(['번호', '분류', '문제', '보기', '선택지 1', '선택지 2', '선택지 3', '선택지 4', '정답 인덱스'], dtype='object')
# 2 : Index(['번호', '분류', '문제', '보기', '선택지 1', '선택지 2', '선택지 3', '선택지 4', '정답 인덱스'], dtype='object')
# 3 : Index(['번호', '분류', '문제', '보기', '선택지 1', '선택지 2', '선택지 3', '선택지 4', '정답 인덱스'], dtype='object')
# 4 : Index(['번호', '분류', '문제', '보기', '선택지 1', '선택지 2', '선택지 3', '선택지 4', '정답 인덱스'], dtype='object')
# 5 : Index(['번호', '분류', '문제', '보기', '선택지 1', '선택지 2', '선택지 3', '선택지 4', '정답 인덱스'], dtype='object')
# 6 : Index(['번호', '분류', '문제', '보기', '선택지 1', '선택지 2', '선택지 3', '선택지 4', '정답 인덱스'], dtype='object')
# 7 : Index(['번호', '분류', '문제', '보기', '선택지 1', '선택지 2', '선택지 3', '선택지 4', '정답 인덱스'], dtype='object')
# 8 : Index(['번호', '분류', '문제', '보기', '선택지 1', '선택지 2', '선택지 3', '선택지 4', '정답 인덱스'], dtype='object')
# 9 : Index(['번호', '분류', '문제', '보기', '선택지 1', '선택지 2', '선택지 3', '선택지 4', '정답 인덱스'], dtype='object')
# 10 : Index(['번호', '분류', '문제', '보기', '선택지 1', '선택지 2', '선택지 3', '선택지 4', '정답 인덱스'], dtype='object')
# 11 : Index([                                                                     1,
#                                                                  'Unnamed: 1',
#                                                       '클렌징 제품에 대한 설명이 틀린 것은?',
#                                                                  'Unnamed: 3',
#                           '클렌징 밀크는 O/W 타입으로 친유성이며 건성, 노화, 민감성 피부에만 사용할 수 있다.',
#        '클렌징 오일은 일반 오일과 다르게 물에 용해되는 특성이 있고 탈수 피부, 민감성 피부, 약건성 피부에 사용하면 효과적이다.',
#                                        '비누는 사용 역사가 가장 오래된 클렌징 제품이고 종류가 다양하다.',
#        '클렌징크림은 친유성과 친수성이 있으며 친유성은 반드시 이중 세안을 해서 클렌징 제품이 피부에 남이 있지 않도록 해야 한다.',
#                                                                         '1.1'],
#       dtype='object')
# 12 : Index(['번호', '분류', '문제', '보기', '선택지 1', '선택지 2', '선택지 3', '선택지 4', '정답 인덱스'], dtype='object')
# 13 : Index(['번호', '분류', '문제', '보기', '선택지 1', '선택지 2', '선택지 3', '선택지 4', '정답 인덱스'], dtype='object')

# %%
df = pd.read_excel('미용사(피부)\미용사(피부)20110417(교사용).xlsx', header=0)
df.head()
# Out:
#    번호  분류                                          문제   보기  \
# 0   1 NaN                       클렌징 제품에 대한 설명이 틀린 것은?  NaN
# 1   2 NaN                     딥 클렌징의 효과와 가장 거리가 먼 것은?  NaN
# 2   3 NaN                     팩의 제거 방법에 따른 분류가 아닌 것은?  NaN
# 3   4 NaN                      클렌징 시술에 대한 내용 중 틀린 것은?  NaN
# 4   5 NaN  피부 분석표 작성시 피부 표면의 혈액순환상태에 따른 분류 표시가 아닌 것은?  NaN
#
#                                                선택지 1  \
# 0  클렌징 밀크는 O/W 타입으로 친유성이며 건성, 노화, 민감성 피부에만 사용할 수 있다.
# 1                                         모공의 노폐물 제거
# 2                         티슈 오프 타입 (Tissue off type)
# 3                  포인트 메이크업 제거시 아이 립 메이크업 리무버를 사용한다.
# 4                              홍반피부(erythrosis skin)
#
#                                                선택지 2  \
# 0  클렌징 오일은 일반 오일과 다르게 물에 용해되는 특성이 있고 탈수 피부, 민감성 피...
# 1                                    화장품의 피부 흡수를 도와줌
# 2                         석고 마스크 타입(gysum mask type)
# 3  방수 (waterproof)마스카라를 한 고객의 경우에는 오일 성분의 아이메이크업 ...
# 4                            심한 홍반피부(couperose skin)
#
#                                                선택지 3  \
# 0               비누는 사용 역사가 가장 오래된 클렌징 제품이고 종류가 다양하다.
# 1                                           노화된 각질제거
# 2                             필 오프 타입(Peel off type)
# 3  클렌징 동작 중 원을 그리는 동작은 얼굴의 위를 향할 때 힘을 빼고 내릴 때는 힘을...
# 4                               주사성 피부(rosacea skin)
#
#                                                선택지 4  정답 인덱스
# 0  클렌징크림은 친유성과 친수성이 있으며 친유성은 반드시 이중 세안을 해서 클렌징 제품...       1
# 1                                  심한 민감성 피부의 민감도 완화       4
# 2                            워서 오프 타입(Wash off type)       2
# 3             클렌징 동작은 근육결에 따르고, 머리쪽을 향하게 하는 것에 유념한다.       3
# 4                    과색소 피부(Hyper pigmentation skin)       4

# %%
folder_path = f'{license}'
file_paths = glob.glob(os.path.join(folder_path, "*.xlsx"))

# 파일들을 저장할 데이터프레임 리스트
questions_df_list = []

# 각 파일을 읽어서 데이터프레임으로 변환 후 리스트에 추가
for file in file_paths:
    df = pd.read_excel(file)
    
    # 파일 이름 추출 후 리스트에 추가
    file_name = os.path.basename(file)
    date_str = file_name.split(f'{license}')[1][:8]  # '20040201' 부분 추출

    # 새로운 'date' 열 추가 (문자열을 날짜 형식으로 변환할 수도 있음)
    # df['made_at'] = pd.to_datetime(date_str, format='%Y%m%d')
    df['made_at'] = pd.to_datetime(date_str, format='%Y%m%d').strftime('%Y-%m-%d')
    df['license'] = license_id
    df = df.drop(columns=['보기', '분류', '선택지 1', '선택지 2', '선택지 3', '선택지 4', '정답 인덱스'])
    df = df.rename(columns={'번호': 'no', '호':'no'})
    df = df.rename(columns={'문제': 'content'})
    df = df.replace(r'\n', ' ', regex=True)
    questions_df_list.append(df)

# %%
questions_df_list
# Out:
# [    no                                            content     made_at  license
#  0    1                            딥클렌징의 효과에 대한 설명이 아닌 것은?  2008-10-05        2
#  1    2              피부 관리를 위해 실시하는 피부상담의 목적과 가장 거리가 먼 것은?  2008-10-05        2
#  2    3          민감성 피부 관리의 마무리단계에 사용될 보습제로 적합한 성분이 아닌 것은?  2008-10-05        2
#  3    4  피부미용실에서 손님에 대한 피부 관리의 과정 중 피부 분석을 통한 고객카드 관리의 ...  2008-10-05        2
#  4    5  도포 후 온도가 40℃ 이상 올라가며, 노화피부 및 건성 피부에 필요한 영양흡수효과...  2008-10-05        2
#  5    6                            피부 관리의 정의와 가장 거리가 먼 것은?  2008-10-05        2
#  6    7                         피부 유형별 관리 방법으로 적합하지 않은 것은?  2008-10-05        2
#  7    8                              매뉴얼테크닉을 적용할 수 있는 경우는?  2008-10-05        2
#  8    9                                     팩의 설명으로 옳은 것은?  2008-10-05        2
#  9   10                     민감성 피부의 화장품 사용에 대한 설명으로 틀린 것은?  2008-10-05        2
#  10  11                               딥클렌징에 대한 설명으로 틀린 것은?  2008-10-05        2
#  11  12                      피부 유형과 화장품의 사용목적이 틀리게 연결된 것은?  2008-10-05        2
#  12  13                 홈케어 관리시에 여드름 피부에 대한 조언으로 맞지 않는 것은?  2008-10-05        2
#  13  14                  포인트 메이크업 클렌징 과정 시 주의할 사항으로 틀린 것은?  2008-10-05        2
#  14  15     매뉴얼테크닉을 이용한 관리 시 그 효과에 영향을 주는 요소와 가장 거리가 먼 것은?  2008-10-05        2
#  15  16          왁스와 머절린(부직포)을 이용한 일시적 제모의 특징으로 가장 적합한 것은?  2008-10-05        2
#  16  17                          일반적인 클렌징에 해당되는 사항이 아닌 것은?  2008-10-05        2
#  17  18                        습포의 효과에 대한 내용과 가장 거리가 먼 것은?  2008-10-05        2
#  18  19                             다음 비타민에 대한 설명 중 틀린 것은?  2008-10-05        2
#  19  20                                자외선에 대한 설명으로 틀린 것은?  2008-10-05        2
#  20  21  피부의 주체를 이루는 층으로서 망상층과 유두층으로 구분되며 피부조직 외에 부속기관인...  2008-10-05        2
#  21  22  진피에 자리하고 있으며 통증이 동반되고, 여드름 피부의 4단계에서 생성되는 것으로 ...  2008-10-05        2
#  22  23                                 기미에 대한 설명으로 틀린 것은?  2008-10-05        2
#  23  24                             피부의 면역에 관한 설명으로 맞는 것은?  2008-10-05        2
#  24  25                             림프액의 기능과 가장 관계가 없는 것은?  2008-10-05        2
#  25  26                           피부의 노화 원인과 가장 관련이 없는 것은?  2008-10-05        2
#  26  27                             멜라닌 세포가 주로 분포되어 있는 곳은?  2008-10-05        2
#  27  28                                    골격계의 기능이 아닌 것은?  2008-10-05        2
#  28  29                        인체의 구성 요소 중 기능적, 구조적 최소단위는?  2008-10-05        2
#  29  30                   담즙을 만들며, 포도당을 글리코겐으로 저장하는 소화기관은?  2008-10-05        2
#  30  31                            신경계에 관련된 설명이 옳게 연결된 것은?  2008-10-05        2
#  31  32            두부의 근을 안면근과 저작근으로 나눌 때 안면근에 속하지 않는 근육은?  2008-10-05        2
#  32  33  근육에 짧은 간격으로 자극을 주면 연축이 합쳐져서 단일 수축보다 큰 힘과 지속적인 ...  2008-10-05        2
#  33  34     조직 사이에서 산소와 영양을 공급하고, 이산화탄소와 대사 노폐물이 교환되는 혈관은?  2008-10-05        2
#  34  35                             다음 중 열을 이용한 기기가 아닌 것은?  2008-10-05        2
#  35  36                        스티머 활용시의 주의사항과 가장 거리가 먼 것은?  2008-10-05        2
#  36  37               적외선등(Infra red lamp)에 대한 설명으로 옳은 것은?  2008-10-05        2
#  37  38                                브러싱에 관한 설명으로 틀린 것은?  2008-10-05        2
#  38  39                                 전기에 대한 설명으로 틀린 것은?  2008-10-05        2
#  39  40             우드램프로 피부상태를 판단할 때 지성 피부는 어떤 색으로 나타나는가?  2008-10-05        2
#  40  41  다음 중 피부상재균의 증식을 억제하는 항균기능을 가지고 있고, 발생한 체취를 억제하...  2008-10-05        2
#  41  42                              화장품을 만들 때 필요한 4대 조건은?  2008-10-05        2
#  42  43  캐리어오일 중 액체상 왁스에 속하고, 인체 피지와 지방산의 조성이 유사하여 피부 친...  2008-10-05        2
#  43  44                               미백 화장품의 메커니즘이 아닌 것은?  2008-10-05        2
#  44  45                                SPF에 대한 설명으로 틀린 것은?  2008-10-05        2
#  45  46                 다음 중 피부에 수분을 공급하는 보습제의 기능을 가지는 것은?  2008-10-05        2
#  46  47                              계면활성제에 대한 설명으로 옳은 것은?  2008-10-05        2
#  47  48                             보건교육의 내용과 관계가 가장 먼 것은?  2008-10-05        2
#  48  49                           보건행정에 대한 설명으로 가장 올바른 것은?  2008-10-05        2
#  49  50                          법정 전염병 중 제3군 전염병에 속하는 것은?  2008-10-05        2
#  50  51                          세균성 식중독이 소화기계 전염병과 다른 점은?  2008-10-05        2
#  51  52  순도 100% 소독약 원액 2mL에 증류수 98mL를 혼합하여 100mL의 소독약을...  2008-10-05        2
#  52  53                          다음 중 자비소독을 하기에 가장 적합한 것은?  2008-10-05        2
#  53  54                            석탄산 소독액에 관한 설명으로 틀린 것은?  2008-10-05        2
#  54  55                           다음 중 가장 강한 살균작용을 하는 광선은?  2008-10-05        2
#  55  56                               다음 중 이·미용사 면허의 발급자는?  2008-10-05        2
#  56  57                          다음 중 공중위생 감시원이 될 수 없는 자는?  2008-10-05        2
#  57  58                 공중위생관리법규상 공중위생영업자가 받아야 하는 위생교육시간은?  2008-10-05        2
#  58  59          공중위생관리법령에 따른 과징금의 부과 및 납부에 관한 사항으로 틀린 것은?  2008-10-05        2
#  59  60                 이·미용사의 면허증을 대여한 때의 1차 위반 행정처분 기준은?  2008-10-05        2,
#      no                                            content     made_at  license
#  0    1                       피부유형별 화장품 사용방법으로 적합하지 않은 것은?  2009-01-18        2
#  1    2                      피부 분석시 사용되는 방법으로 가장 거리가 먼 것은?  2009-01-18        2
#  2    3           슬리밍 제품을 이용한 관리에서 최종 마무리 단계에서 시행해야 하는 것은?  2009-01-18        2
#  3    4            메뉴얼 테크닉 기법 중 닥터 자켓법에 관한 설명으로 가장 적합한 것은?  2009-01-18        2
#  4    5                            다음은 어떤 베이스 오일을 설명한 것인가?  2009-01-18        2
#  5    6                         피부미용에 대한 설명으로 가장 거리가 먼 것은?  2009-01-18        2
#  6    7                                 클렌징에 대한 설명이 아닌 것은?  2009-01-18        2
#  7    8                                   천연과일에서 추출한 필링제는?  2009-01-18        2
#  8    9                                건성피부의 관리방법으로 틀린 것은?  2009-01-18        2
#  9   10           피부관리 후 마무리 동작에서 수렴작용을 할 수 있는 가장 적합한 방법은?  2009-01-18        2
#  10  11                        계절에 따른 피부 특성 분석으로 옳지 않은 것은?  2009-01-18        2
#  11  12             딥클렌징시 스크럽 제품을 사용할 때 주의해야 할 사항 중 틀린 것은?  2009-01-18        2
#  12  13                            팩의 사용방법에 대한 내용 중 틀린 것은?  2009-01-18        2
#  13  14     다음 중 인체의 임파선을 통한 노폐물의 이동을 통해 해독작용을 도와주는 관리방법은?  2009-01-18        2
#  14  15  메뉴얼 테크닉의 동작 중 부드럽게 스쳐가는 동작으로 처음과 마지막이나 연결동작으로 ...  2009-01-18        2
#  15  16                                제모의 종류와 방법 중 옳은 것은?  2009-01-18        2
#  16  17                                마스크에 대한 설명 중 틀린 것은?  2009-01-18        2
#  17  18                           클렌징 시 주의해야 할 사항 중 틀린 것은?  2009-01-18        2
#  18  19                       아토피성 피부에 관계되는 설명으로 옳지 않은 것은?  2009-01-18        2
#  19  20  피지와 땀의 분비 저하로 유,수분의 균형이 정상적이지 못하고, 피부결이 얇으며 탄력...  2009-01-18        2
#  20  21             피부 색소를 퇴색시키며 기미, 주근깨 등의 치료에 주로 쓰이는 것은?  2009-01-18        2
#  21  22                   성인의 경우 피부가 차지하는 부중은 체중의 약 몇 %인가?  2009-01-18        2
#  22  23                        여드름 발생의 주요 원인과 가장 거리가 먼 것은?  2009-01-18        2
#  23  24                                   피부노화 현상으로 옳은 것은?  2009-01-18        2
#  24  25                             다음 중 표피층을 순서대로 나열한 것은?  2009-01-18        2
#  25  26                        다음 중 멜라닌 세포에 관한 설명으로 틀린 것은?  2009-01-18        2
#  26  27                                   다음 중 원발진이 아닌 것은?  2009-01-18        2
#  27  28                                     혈액의 기능이 아닌 것은?  2009-01-18        2
#  28  29                      다음 중 뼈의 기능으로 맞는 것을 모두 나열한 것은?  2009-01-18        2
#  29  30                                 세포에 대한 설명으로 틀린 것은?  2009-01-18        2
#  30  31     다음 중 위팔을 올리거나 내릴 때 또는 바깥쪽으로 돌릴 때 사용되는 근육의 명칭은?  2009-01-18        2
#  31  32                                  다음 중 소화기계가 아닌 것은?  2009-01-18        2
#  32  33                          다음 중 웃을 때 사용하는 근육이 아닌 것은?  2009-01-18        2
#  33  34                                골격근에 대한 설명으로 맞는 것은?  2009-01-18        2
#  34  35                                 이온에 대한 설명으로 틀린 것은?  2009-01-18        2
#  35  36                    브러시(brush,프리마돌) 사용법으로 옳지 않은 것은?  2009-01-18        2
#  36  37                          스티머기기의 사용방법으로 적합하지 않은 것은?  2009-01-18        2
#  37  38    수분측정기로 표피의 수분 함유량을 측정하고자 할 때 고려해야 하는 내용이 아닌 것은?  2009-01-18        2
#  38  39                          디스인크러스테이션에 대한 설명 중 틀린 것은?  2009-01-18        2
#  39  40  눈으로 판별하기 어려운 피부의 심층상태 및 문제점을 명확하게 분별할 수 있는, 특수...  2009-01-18        2
#  40  41  핸드케어제품 중 사용할 때 물을 사용하지 않고 직접 바르는 것으로 피부 청결 및 소...  2009-01-18        2
#  41  42                          크림 파운데이션에 대한 설명 중 알맞은 것은?  2009-01-18        2
#  42  43  땀의 분비로 인한 냄새와 세균의 증식을 억제하기 위해 주로 겨드랑이 부위에 사용하는...  2009-01-18        2
#  43  44                      다음 중 물에 오일성분이 혼합되어 있는 유화 상태는?  2009-01-18        2
#  44  45          아로마테라피에 사용되는 아로마 오일에 대한 설명 중 가장 거리가 먼 것은?  2009-01-18        2
#  45  46                            자외선 차단제에 대한 설명 중 틀린 것은?  2009-01-18        2
#  46  47                      다음 중 기능성 화장품의 범위에 해당하지 않는 것은?  2009-01-18        2
#  47  48               상수의 수질오염 분석 시 대표적인 생물학적 지표로 이용되는 것은?  2009-01-18        2
#  48  49                          자연능동면역 중 감염면역만 형성되는 전염병은?  2009-01-18        2
#  49  50                                  발열증상이 가장 심한 식중독은?  2009-01-18        2
#  50  51                 다음 중 가장 대표적인 보건 수준 평가기준으로 사용되는 것은?  2009-01-18        2
#  51  52                      소독약의 사용 및 보존상의 주의 점으로서 틀린 것은?  2009-01-18        2
#  52  53                        소독장비 사용시 주의해야 할 사항 중 옳은 것은?  2009-01-18        2
#  53  54  고압증기 멸균법에 있어 20lBS,126.5C의 상태에서 몇 분간 처리하는 것이 가...  2009-01-18        2
#  54  55               이·미용업소에서 수건 소독에 가장 많이 사용되는 물리적 소독법은?  2009-01-18        2
#  55  56                         공중위생관리법 상 이·미용 업소의 조명 기준은?  2009-01-18        2
#  56  57              공중위생관리법상 위생서비스 수준의 평가에 대한 설명 중 맞는 것은?  2009-01-18        2
#  57  58  이·미용업 영업자가 공중위생관리법을 위반하여 관계행정기관의 장의 요청이 있는 때에는...  2009-01-18        2
#  58  59  행정처분 대상자 중 중요처분 대상자에게 청문을 실시할 수 있다. 그 청문대상이 아닌...  2009-01-18        2
#  59  60                              다음 중 ( )안에 가장 적합한 것은?  2009-01-18        2,
#      no                                            content     made_at  license
#  0    1  물의 수압을 이용해 혈액순환을 촉진시켜 체내의 독소배출, 세포재생 등의 효과를 증진...  2009-03-29        2
#  1    2  글리콜산이나 젖산을 이용하여 각질층에 침투시키는 방법으로 각질세포의 응집력을 약화시...  2009-03-29        2
#  2    3                             다음에서 설명하는 팩(마스크)의 재료는?  2009-03-29        2
#  3    4                              클렌징의 목적과 가장 거리가 먼 것은?  2009-03-29        2
#  4    5                                다음 중 필링의 대상이 아닌 것은?  2009-03-29        2
#  5    6                     피부 관리 시 마무리 동작에 대한 설명 중 틀린 것은?  2009-03-29        2
#  6    7          신체 부위별 관리의 효과를 극대화시키기 위한 방법과 가장 거리가 먼 것은?  2009-03-29        2
#  7    8                         제모 관리에서 왁스 제모법의 장점이 아닌 것은?  2009-03-29        2
#  8    9                      매뉴얼테크닉 시술 시 주의해야 할 사항이 아닌 것은?  2009-03-29        2
#  9   10                              제모시술 중 올바른 방법이 아닌 것은?  2009-03-29        2
#  10  11                              표피수분부족 피부의 특징이 아닌 것은?  2009-03-29        2
#  11  12                     매뉴얼 테크닉의 기본 동작에 대한 설명으로 틀린 것은?  2009-03-29        2
#  12  13                        입술 화장을 제거하는 방법으로 가장 적합한 것은?  2009-03-29        2
#  13  14                                    화장수의 작용이 아닌 것은?  2009-03-29        2
#  14  15                                 팩 중 아줄렌 팩의 주된 효과는?  2009-03-29        2
#  15  16                                   피부미용의 기능이 아닌 것은?  2009-03-29        2
#  16  17                        피부미용의 관점에서 딥클렌징의 목적이 아닌 것은?  2009-03-29        2
#  17  18                       여드름 피부에 직접 사용하기에 가장 좋은 아로마는?  2009-03-29        2
#  18  19                               피부구조에 대한 설명 중 틀린 것은?  2009-03-29        2
#  19  20  사춘기 이후에 주로 분비가 되며, 모공을 통하여 분비되어 독특한 체취를 발생시키는 것은?  2009-03-29        2
#  20  21                                 피부 표피 중 가장 두꺼운 층은?  2009-03-29        2
#  21  22                              각 비타민의 효능 설명 중 옳은 것은?  2009-03-29        2
#  22  23                피부의 각질층에 존재하는 세포간지질 중 가장 많이 함유된 것은?  2009-03-29        2
#  23  24                      콜라겐(collagen)에 대한 설명으로 틀린 것은?  2009-03-29        2
#  24  25                               성인이 하루에 분비하는 피지의 양은?  2009-03-29        2
#  25  26                              광노화의 반응과 가장 거리가 먼 것은?  2009-03-29        2
#  26  27                               지성피부에 대한 설명 중 틀린 것은?  2009-03-29        2
#  27  28                                    혈액의 기능으로 틀린 것은?  2009-03-29        2
#  28  29           인체의 각 주요 호르몬의 기능 저하에 따라 나타나는 현상으로 틀린 것은?  2009-03-29        2
#  29  30     세포 내에서 호흡생리를 담당하고 이화작용과 동화작용에 의해 에너지를 생산하는 곳은?  2009-03-29        2
#  30  31                           골과 골 사이의 충격을 흡수하는 결합조직은?  2009-03-29        2
#  31  32                               췌장에서 분비되는 단백질 분해효소는?  2009-03-29        2
#  32  33                                평활근에 대한 설명 중 틀린 것은?  2009-03-29        2
#  33  34                               다음 보기의 사항에 해당되는 신경은?  2009-03-29        2
#  34  35                        진동브러쉬(Frimator)의 효과가 아닌 것은?  2009-03-29        2
#  35  36                                    전류의 설명으로 옳은 것은?  2009-03-29        2
#  36  37       디스인크러스테이션(disincrustation)을 가급적 피해야 할 피부유형은?  2009-03-29        2
#  37  38                     적외선 미용기기를 사용할 때의 주의사항으로 옳은 것은?  2009-03-29        2
#  38  39  갈바닉 전류 중 음극(-)을 이용한 것으로 제품을 피부로 스며들게 하기 위해 사용하...  2009-03-29        2
#  39  40          증기연무기(Steamer)를 사용할 때 얻는 효과와 가장 거리가 먼 것은?  2009-03-29        2
#  40  41                            기능성 화장품에 대한 설명으로 옳은 것은?  2009-03-29        2
#  41  42                            자외선 차단제에 대한 설명으로 옳은 것은?  2009-03-29        2
#  42  43                  다음 중 향수의 부향률이 높은 것부터 순서대로 나열된 것은?  2009-03-29        2
#  43  44                            화장품의 4대 요건에 해당되지 않는 것은?  2009-03-29        2
#  44  45                           다음의 설명에 해당되는 천연향의 추출방법은?  2009-03-29        2
#  45  46                        바디샴푸에 요구되는 기능과 가장 거리가 먼 것은?  2009-03-29        2
#  46  47  세정작용과 기포형성작용이 우수하여 비누, 샴푸, 클렌징폼 등에 주로 사용되는 계면활...  2009-03-29        2
#  47  48                                식중독에 관한 설명으로 옳은 것은?  2009-03-29        2
#  48  49                          보건행정의 제 원리에 관한 것으로 맞는 것은?  2009-03-29        2
#  49  50                   다음 중 같은 병원체에 의하여 발생하는 인수공통 전염병은?  2009-03-29        2
#  50  51                           공중보건학의 개념과 가장 관계가 적은 것은?  2009-03-29        2
#  51  52        혈청이나 약제, 백신 등 열에 불안정한 액체의 멸균에 주로 이용되는 멸균법은?  2009-03-29        2
#  52  53  석탄산의 90배 희석액과 어느 소독약의 180배 희석액이 같은 조건하에서 같은 소독...  2009-03-29        2
#  53  54                        고압증기멸균기의 소독대상물로 적합하지 않은 것은?  2009-03-29        2
#  54  55                                멸균의 의미로 가장 적합한 표현은?  2009-03-29        2
#  55  56                  이·미용사 영업자의 지위를 승계 받을 수 있는 자의 자격은?  2009-03-29        2
#  56  57  미용업 영업자가 영업소 폐쇄 명령을 받고도 계속하여 영업을 하는 때에 시장, 군수,...  2009-03-29        2
#  57  58                           공중위생관리법상() 속에 가장 적합한 것은?  2009-03-29        2
#  58  59  미용업자가 점빼기, 귓볼뚫기, 쌍커풀수술, 문신, 박피술 그 밖에 이와 유사한 의료...  2009-03-29        2
#  59  60                                과태료에 대한 설명 중 틀린 것은?  2009-03-29        2,
#      no                                            content     made_at  license
#  0    1                             필오프 타입 마스크의 특징이 아닌 것은?  2009-07-12        2
#  1    2     매뉴얼 테크닉의 기본 동작 중 하나인 쓰다듬기에 대한 내용과 가장 거리가 먼 것은?  2009-07-12        2
#  2    3                         모세혈관 확장피부에 효과적인 성분이 아닌 것은?  2009-07-12        2
#  3    4                                 다음의 설명에 가장 적합한 팩은?  2009-07-12        2
#  4    5                       피부유형별 적용 화장품 성분이 맞게 짝지어진 것은?  2009-07-12        2
#  5    6                               온습포의 작용으로 볼 수 없는 것은?  2009-07-12        2
#  6    7                       딥 클렌징의 효과 및 목적과 가장 거리가 먼 것은?  2009-07-12        2
#  7    8             다음 중 세정력이 우수하며, 지성, 여드름피부에 가장 적합한 제품은?  2009-07-12        2
#  8    9                                    제모의 설명으로 틀린 것은?  2009-07-12        2
#  9   10                           클렌징 제품의 올바른 선택조건이 아닌 것은?  2009-07-12        2
#  10  11             피부관리 후 피부미용사가 마무리해야 할 사항과 가장 거리가 먼 것은?  2009-07-12        2
#  11  12                                  지성피부의 특징으로 맞는 것은?  2009-07-12        2
#  12  13          손가락이나 손바닥으로 연속적인 쓰다듬기 동작을 하는 매뉴얼 테크닉 방법은?  2009-07-12        2
#  13  14               다음 중 스크럽 성분의 딥클렌징을 피하는 것이 가장 좋은 피부는?  2009-07-12        2
#  14  15                               바디 랩에 관한 설명으로 틀린 것은?  2009-07-12        2
#  15  16                     피부미용의 개념에 대한 설명으로 가장 거리가 먼 것은?  2009-07-12        2
#  16  17                     왁스를 이용한 제모의 부적용증과 가장 거리가 먼 것은?  2009-07-12        2
#  17  18      건성피부, 중성피부, 지성 피부를 구분하는 가장 기본적인 피부 유형 분석 기준은?  2009-07-12        2
#  18  19                             자외선의 영향으로 인한 부정적인 효과는?  2009-07-12        2
#  19  20         땀의 분비가 감소하고 갑상선 기능의 저하, 신경계 질환의 원인이 되는 것은?  2009-07-12        2
#  20  21       장기간에 걸쳐 반복하여 긁거나 비벼서 표피가 건조하고 가죽처럼 두꺼워진 상태는?  2009-07-12        2
#  21  22             화상의 구분 중 홍반, 부종, 통증뿐만 아니라 수포를 형성하는 것은?  2009-07-12        2
#  22  23  원주형의 세포가 단층으로 이어져 있으며 각질형성세포와 색소형성세포가 존재하는 피부세...  2009-07-12        2
#  23  24                       피부에서 피지가 하는 작용과 관계가 가장 먼 것은?  2009-07-12        2
#  24  25                    각화유리질과립은 피부 표피의 어떤 층에 주로 존재하는가?  2009-07-12        2
#  25  26                                    다음 중 진피의 구성세포는?  2009-07-12        2
#  26  27                         기미, 주근깨 피부관리에 가장 적합한 비타민은?  2009-07-12        2
#  27  28                                   안륜근의 설명으로 맞는 것은?  2009-07-12        2
#  28  29       근육의 기능에 따른 분류에서 서로 반대되는 작용을 하는 근육을 무엇이라 하는가?  2009-07-12        2
#  29  30                                    골격근의 기능이 아닌 것은?  2009-07-12        2
#  30  31                 원형질막을 통한 물질의 이동 과정에 관한 설명 중 틀린 것은?  2009-07-12        2
#  31  32                                  척주에 대한 설명이 아닌 것은?  2009-07-12        2
#  32  33  안면의 피부와 저작근에 존재하는 감각신경과 운동신경의 혼합신경으로 뇌신경 중 가장 ...  2009-07-12        2
#  33  34                                        림프의 주된 기능은?  2009-07-12        2
#  34  35  피부를 분석 시 고객과 관리사가 동시에 피부상태를 보면서 분석하기에 가장 적합한 피...  2009-07-12        2
#  35  36                           바이브레이터기의 올바른 사용법이 아닌 것은?  2009-07-12        2
#  36  37                                  갈바닉 전류에서 음극의 효과는?  2009-07-12        2
#  37  38                             직류와 교류에 대한 설명으로 옳은 것은?  2009-07-12        2
#  38  39               다음 보기와 같은 내용은 어떠한 타입의 피부 관리 중점 사항인가?  2009-07-12        2
#  39  40                            고주파 직접법의 주 효과에 해당하는 것은?  2009-07-12        2
#  40  41            아로마오일을 피부에 효과적으로 침투시키기 위해 사용하는 식물성 오일은?  2009-07-12        2
#  41  42  메이크업 화장품 중에서 인료가 균일하게 분산되어 있는 형태로 대부분 O/W형 유화타...  2009-07-12        2
#  42  43                 여드름 피부용 화장품에 사용되는 성분과 가장 거리가 먼 것은?  2009-07-12        2
#  43  44  각질제거용 화장품에 주로 쓰이는 것으로 죽은 각질을 빨리 떨어져 나가게 하고 건강한...  2009-07-12        2
#  44  45                         아로마 오일에 대한 설명으로 가장 적절한 것은?  2009-07-12        2
#  45  46                            화장품의 분류에 관한 설명 중 틀린 것은?  2009-07-12        2
#  46  47     유아용 제품과 저자극성 제품에 많이 사용되는 계면활성제에 대한 설명 중 옳은 것은?  2009-07-12        2
#  47  48                        전염병예방법 중 제 1군 전염병에 해당되는 것은?  2009-07-12        2
#  48  49         다음 중 오염된 주사기, 면도날 등으로 인해 감염이 잘 되는 만성 전염병은?  2009-07-12        2
#  49  50                           공중보건에 대한 설명으로 가장 적절한 것은?  2009-07-12        2
#  50  51                                     독소형 식중독의 원인균은?  2009-07-12        2
#  51  52                   다음 중 아포를 형성하는 세균에 대한 가장 좋은 소독법은?  2009-07-12        2
#  52  53  여러 가지 물리화학적 방법으로 병원성 미생물을 가능한 제거하여 사람에게 감염의 위험...  2009-07-12        2
#  53  54                              소독약이 고체인 경우 1% 수용액이란?  2009-07-12        2
#  54  55                                     호기성 세균이 아닌 것은?  2009-07-12        2
#  55  56  갑이라는 미용업영업자가 처음으로 손님에게 윤락행위를 제공하다가 적발되었다. 이 경우...  2009-07-12        2
#  56  57  보건복지부장관은 공중위생관리법에 의한 권한의 일부를 무엇이 정하는 바에 의해 시 도...  2009-07-12        2
#  57  58              면허의 정지명령을 받은 자는 그 면허증을 누구에게 제출해야 하는가?  2009-07-12        2
#  58  59                               이·미용업의 준수사항으로 틀린 것은?  2009-07-12        2
#  59  60     이·미용업을 승계할 수 있는 경우가 아닌 것은? (단, 면허를 소지한 자에 한 함)  2009-07-12        2,
#      no                                            content     made_at  license
#  0    1                    클렌징 시술 준비과정의 유의사항과 가장 거리가 먼 것은?  2009-09-27        2
#  1    2                                지성 피부를 위한 피부관리 방법은?  2009-09-27        2
#  2    3  고객이 처음 내방하였을 때 피부관리에 대한 첫 상담과정에서 고객이 얻는 효과와 가장...  2009-09-27        2
#  3    4                              왁스 시술에 대한 내용 중 옳은 것은?  2009-09-27        2
#  4    5  눈썹이나 겨드랑이 등과 같이 연약한 피부의 제모에 사용하며, 부직포를 사용하지 않고...  2009-09-27        2
#  5    6                                 워쉬오프 타입의 팩이 아닌 것은?  2009-09-27        2
#  6    7                               아래 설명과 가장 가까운 피부타입은?  2009-09-27        2
#  7    8                           피부미용의 개념에 대한 설명 중 틀린 것은?  2009-09-27        2
#  8    9                                 피부 관리 시술단계가 옳은 것은?  2009-09-27        2
#  9   10                                 습포에 대한 설명으로 맞는 것은?  2009-09-27        2
#  10  11                    다음 중 눈 주위에 가장 적합한 매뉴얼 테크닉의 방법은?  2009-09-27        2
#  11  12                           딥클렌징의 효과에 대한 설명으로 틀린 것은?  2009-09-27        2
#  12  13                             매뉴얼 테크닉의 주의 사항이 아닌 것은?  2009-09-27        2
#  13  14  관리방법 중 수요법(water therapy, hydrotherapy)시 지켜야 할...  2009-09-27        2
#  14  15                                     딥클렌징 방법이 아닌것은?  2009-09-27        2
#  15  16                 피부관리 시 매뉴얼테크닉을 하는 목적과 가장 거리가 먼 것은?  2009-09-27        2
#  16  17                        콜라겐 벨벳마스크는 어떤 타입이 주로 사용되는가?  2009-09-27        2
#  17  18                      셀룰라이트 관리에서 중점적으로 행해야 할 관리방법은?  2009-09-27        2
#  18  19  원주형 세포가 단층적으로 이어져 있으며 각질형성세포와 색소형성세포가 존재하는 피부세...  2009-09-27        2
#  19  20                    산소 라디칼 방어에서 가장 중심적인 역할을 하는 효소는?  2009-09-27        2
#  20  21                                다음 중 피부의 기능이 아닌 것은?  2009-09-27        2
#  21  22                       내인성 노화가 진행될 때 감소현상을 나타내는 것은?  2009-09-27        2
#  22  23                    다음 중 주름살이 생기는 요인으로 가장 거리가 먼 것은?  2009-09-27        2
#  23  24     콜레스테롤의 대사 및 해독작용과 스테로이드 호르몬의 합성과 관계있는 무과립 세포는?  2009-09-27        2
#  24  25                                 다음 내용과 가장 관계있는 것은?  2009-09-27        2
#  25  26                                아포크린한선의 설명으로 틀린 것은?  2009-09-27        2
#  26  27                            다음 중 가장 이상적인 피부의 pH범위는?  2009-09-27        2
#  27  28                성장기에 있어 뼈의 길이 성장이 일어나는 곳을 무엇이라 하는가?  2009-09-27        2
#  28  29  섭취된 음식물중의 영양물질을 산화시켜 인체에 필요한 에너지를 생성해 내는 세포 소기관은?  2009-09-27        2
#  29  30                                자율신경의 지배를 받는 민무늬근은?  2009-09-27        2
#  30  31                    인체 내의 화학물질 중 근육 수축에 주로 관여하는 것은?  2009-09-27        2
#  31  32                          혈관의 구조에 관한 설명 중 옳지 않은 것은?  2009-09-27        2
#  32  33  소화선(소화샘)으로써 소화액을 분비하는 동시에 호르몬을 분비하는 혼합선(내/외분비선...  2009-09-27        2
#  33  34                                        신경계의 기본세포는?  2009-09-27        2
#  34  35             고주파 피부미용기기의 사용방법 중 간접법에 대한 설명으로 옳은 것은?  2009-09-27        2
#  35  36         피지, 연포가 있는 피부 부위의 우드램프(wood lamp)의 반응 색상은?  2009-09-27        2
#  36  37                 칼라테라피 기기에서 빨강 색광의 효과와 가장 거리가 먼 것은?  2009-09-27        2
#  37  38              클렌징이나 딥클렌징 단계에서 사용하는 기기와 가장 거리가 먼 것은?  2009-09-27        2
#  38  39                                  전류에 대한 내용이 틀린 것은?  2009-09-27        2
#  39  40                              이온에 대한 설명으로 옳지 않은 것은?  2009-09-27        2
#  40  41                                   향수의 구비요건이 아닌 것은?  2009-09-27        2
#  41  42                             계면활성제에 대한 설명 중 잘못된 것은?  2009-09-27        2
#  42  43                       다음 중 기초화장품의 필요성에 해당되지 않는 것은?  2009-09-27        2
#  43  44                                아하(AHA)의 설명이 아닌 것은?  2009-09-27        2
#  44  45                          화장품과 의약품의 차이를 바르게 정의한 것은?  2009-09-27        2
#  45  46  비누의 제조방법 중 지방산의 글리세린에스테르와 알카리를 함께 가열하면 유지가 가수 ...  2009-09-27        2
#  46  47                    샤워 코롱(Shower cologne)이 속하는 분류는?  2009-09-27        2
#  47  48                     다음 중 동물과 전염병의 병원소로 연결이 잘못된 것은?  2009-09-27        2
#  48  49      다음 중 식품의 혐기성 상태에서 발육하여 신경계 증상이 주 증상으로 나타는 것은?  2009-09-27        2
#  49  50                          전염병예방법상 제 1군 전염병에 속하는 것은?  2009-09-27        2
#  50  51  한 지역이나 국가의 공중보건을 평가하는 기초자료로 가장 신뢰성 있게 인정되고 있는 것은?  2009-09-27        2
#  51  52              다음 중 음료수 소독에 사용되는 소독 방법과 가장 거리가 먼 것은?  2009-09-27        2
#  52  53  보통 상처의 표면에 소독하는데 이용하며 발생기 산소가 강력한 산화력으로 미생물을 살...  2009-09-27        2
#  53  54                       알코올 소독의 미생물 세포에 대한 주된 작용기전은?  2009-09-27        2
#  54  55                          자비소독에 관한 내용으로 적합하지 않은 것은?  2009-09-27        2
#  55  56   공중위생영업소의 위생관리수준을 향상시키기 위하여 위생 서비스 평가계획을 수립하는 자는?  2009-09-27        2
#  56  57      신고를 하지 아니하고 영업소의 소재를 변경한 때 1차 위반 시의 행정처분 기준은?  2009-09-27        2
#  57  58         이·미용업의 영업신고를 하지 아니하고 업소를 개설한 자에 대한 법적 조치는?  2009-09-27        2
#  58  59             다음 중 법에서 규정하는 명예공중위생감시원의 위촉대상자가 아닌 것은?  2009-09-27        2
#  59  60  소독을 한 기구와 소독을 하지 아니한 기구를 각각 다른 용기에 넣어 보관하지 아니한...  2009-09-27        2,
#      no                                            content     made_at  license
#  0    1                                   딥클렌징의 분류가 옳은 것은?  2010-01-31        2
#  1    2  다음 중 노폐물과 독소 및 과도한 체액의 배출을 원활하게 하는 효과에 가장 적합한 ...  2010-01-31        2
#  2    3                          안면 클렌징 시술시의 주의사항 중 틀린 것은?  2010-01-31        2
#  3    4                        밑줄 친 내용에 대한 범위의 설명으로 맞는 것은?  2010-01-31        2
#  4    5  일시적 제모방법 가운데 겨드랑이 및 다리의 털을 제거하기 위해 피부미용실에서 가장 ...  2010-01-31        2
#  5    6                                 효소필링이 적합하지 않은 피부는?  2010-01-31        2
#  6    7                      상담 시 고객에 대해 취해야 할 사항 중 옳은 것은?  2010-01-31        2
#  7    8                                 습포에 대한 설명으로 틀린 것은?  2010-01-31        2
#  8    9                            건성 피부의 특징과 가장 거리가 먼 것은?  2010-01-31        2
#  9   10                                      팩의 목적이 아닌 것은?  2010-01-31        2
#  10  11                     림프 드레니지를 금해야 하는 증상에 속하지 않은 것은?  2010-01-31        2
#  11  12                            피부유형에 맞는 화장품 선택이 아닌 것은?  2010-01-31        2
#  12  13  매뉴얼 테크닉 시 가장 많이 이용되는 기술로 손바닥을 평평하게 하고 손가락을 약간 ...  2010-01-31        2
#  13  14                             화학적 제모와 관련된 설명이 틀린 것은?  2010-01-31        2
#  14  15                                 클렌징 순서가 가장 적합한 것은?  2010-01-31        2
#  15  16                         매뉴얼 테크닉 시술에 대한 내용으로 틀린 것은?  2010-01-31        2
#  16  17                 레몬 아로마 에센셜 오일의 사용과 관련된 설명으로 틀린 것은?  2010-01-31        2
#  17  18     다음 중 피지분비가 많은 지성, 여드름성 피부의 노폐물 제거에 가장 효과적인 팩은?  2010-01-31        2
#  18  19  체내에서 근육 및 신경의 자극 전도, 삼투압 조절 등의 작용을 하며, 식욕에 관계가...  2010-01-31        2
#  19  20                           접촉성 피부염의 주된 알러지원이 아닌 것은?  2010-01-31        2
#  20  21                              다음 중 원발진에 해당하는 피부변화는?  2010-01-31        2
#  21  22  식후 12~16시간 경과되어 정신적, 육체적으로 아무것도 하지 않고 가장 안락한 자...  2010-01-31        2
#  22  23                    표피 중에서 피부로부터 수분이 증발하는 것을 막는 층은?  2010-01-31        2
#  23  24                          다음 내용에 해당하는 세포질 내부의 구조물은?  2010-01-31        2
#  24  25                             에크린 한선에 대한 설명으로 틀린 것은?  2010-01-31        2
#  25  26                      셀룰라이트(cellulite)의 설명으로 옳은 것은?  2010-01-31        2
#  26  27  피부에 계속적인 압박으로 생기는 각질층의 증식현상이며, 원추형의 국한성 비후증으로 ...  2010-01-31        2
#  27  28                              신경계 중 중추신경계에 해당되는 것은?  2010-01-31        2
#  28  29                          세포막을 통한 물질의 이동 방법이 아닌 것은?  2010-01-31        2
#  29  30             혈액의 구성 물질로 항체생산과 감염의 조절에 가장 관계가 깊은 것은?  2010-01-31        2
#  30  31                               뇨의 생성 및 배설과정이 아닌 것은?  2010-01-31        2
#  31  32                               다음 중 뼈의 기본구조가 아닌 것은?  2010-01-31        2
#  32  33  내분비와 외분비를 겸한 혼합성 기관으로 3대 영양소를 분해할 수 있는 소화효소를 모...  2010-01-31        2
#  33  34                                승모근에 대한 설명으로 틀린 것은?  2010-01-31        2
#  34  35                        피부에 미치는 갈바닉 전류의 양극(+)의 효과는?  2010-01-31        2
#  35  36                   테슬라 전류(Tesla current)가 사용되는 기기는?  2010-01-31        2
#  36  37                              스티머 사용 시 주의사항이 아닌 것은?  2010-01-31        2
#  37  38                       지성피부의 면포추출에 사용하기 가장 적합한 기기는?  2010-01-31        2
#  38  39                        피부를 분석할 때 사용하는 기기로 짝지어진 것은?  2010-01-31        2
#  39  40                          괄호 안에 알맞은 말이 순서대로 나열된 것은?  2010-01-31        2
#  40  41                              다음 화장품 중 그 분류가 다른 것은?  2010-01-31        2
#  41  42                           다음 중 기능성 화장품의 영역이 아닌 것은?  2010-01-31        2
#  42  43                               다음 중 바디용 화장품이 아닌 것은?  2010-01-31        2
#  43  44               팩에 사용되는 주성분 중 피막제 및 점도 증가제로 사용되는 것은?  2010-01-31        2
#  44  45                            화장품의 사용목적과 가장 거리가 먼 것은?  2010-01-31        2
#  45  46   피부 거칠음의 개선, 미백, 탈모방지 등의 피부, 면역학 등을 연구하는 유용성 분야는?  2010-01-31        2
#  46  47                         아로마 오일의 사용법 중 확산법으로 맞는 것은?  2010-01-31        2
#  47  48                    다음 중 파리가 매개할 수 있는 질병과 거리가 먼 것은?  2010-01-31        2
#  48  49                             법정 감염병 중 제2군에 해당되는 것은?  2010-01-31        2
#  49  50                           질병전파의 개달물(介達物)에 해당되는 것은?  2010-01-31        2
#  50  51  식품의 혐기성 상태에서 발육하여 체외독소로서 신경독소를 분비하며 치명률이 가장 높은...  2010-01-31        2
#  51  52                         다음 중 상처나 피부 소독에 가장 적합한 것은?  2010-01-31        2
#  52  53                            승홍에 소금을 섞었을 때 일어나는 현상은?  2010-01-31        2
#  53  54                      일반적으로 사용하는 소독제로서 에탄올의 적정 농도는?  2010-01-31        2
#  54  55  인체에 질병을 일으키는 병원체 중 대체로 살아있는 세포에서만 증식하고 크기가 가장 ...  2010-01-31        2
#  55  56      미용영업자가 시장, 군수, 구청장에게 변경 신고를 하여야 하는 사항이 아닌 것은?  2010-01-31        2
#  56  57    이·미용사가 이·미용업소 외의 장소에서 이·미용을 한 경우 3차 위반 행정처분기준은?  2010-01-31        2
#  57  58               행정처분 사항 중 1차 위반 시 영업장 폐쇄명령에 해당하는 것은?  2010-01-31        2
#  58  59  위생서비스평가의 결과에 따른 위생관리등급별로 영업소에 대한 위생감시를 실시할 때의 ...  2010-01-31        2
#  59  60                                   위생교육 대상자가 아닌 것은?  2010-01-31        2,
#      no                                            content     made_at  license
#  0    1                              피부미용사의 피부분석방법이 아닌 것은?  2010-03-28        2
#  1    2                             림프드레니지의 대상이 되지 않는 피부는?  2010-03-28        2
#  2    3                       셀룰라이트(cellulite)의 원인이 아닌 것은?  2010-03-28        2
#  3    4                     클렌징 제품과 그에 대한 설명이 바르게 짝지어진 것은?  2010-03-28        2
#  4    5                                 팩과 관련한 내용 중 틀린 것은?  2010-03-28        2
#  5    6                       벨벳 마스크 사용 시 기포를 제거해야 하는 이유는?  2010-03-28        2
#  6    7                            딥클렌징에 관한 설명으로 옳지 않은 것은?  2010-03-28        2
#  7    8                                   딥클렌징의 효과로 틀린 것은?  2010-03-28        2
#  8    9         피부미용 시 처음과 마지막 동작 또는 연결동작으로 이용되는 매뉴얼 테크닉은?  2010-03-28        2
#  9   10                           피부유형과 관리 목적과의 연결이 틀린 것은?  2010-03-28        2
#  10  11  매뉴얼 테크닉의 기본 동작 중 신경조직을 자극하여 혈액순환을 촉진시켜 피부 탄력성 ...  2010-03-28        2
#  11  12                 피부 관리실에서 피부 관리시 마무리관리에 해당하지 않는 것은?  2010-03-28        2
#  12  13                                   다음 중 화학적인 제모방법은?  2010-03-28        2
#  13  14                                 매뉴얼테크닉의 효과가 아닌 것은?  2010-03-28        2
#  14  15                        왁스를 이용한 제모 방법으로 적합하지 않은 것은?  2010-03-28        2
#  15  16                    피부유형별 화장품사용 시 AHA의 적용피부가 아닌 것은?  2010-03-28        2
#  16  17                               피부유형에 대한 설명 중 틀린 것은?  2010-03-28        2
#  17  18                   클렌징 제품의 선택과 관련된 내용과 가장 거리가 먼 것은?  2010-03-28        2
#  18  19                                피지선에 대한 내용으로 틀린 것은?  2010-03-28        2
#  19  20                        켈로이드는 어떤 조직이 비정상으로 성장한 것인가?  2010-03-28        2
#  20  21    성장촉진, 생리대사의 보조역할, 신경안정과 면역기능 강화 등의 역할을 하는 영양소는?  2010-03-28        2
#  21  22  교원섬유(collagen)와 탄력섬유(elastin)로 구성되어 있어 강한 탄력성을...  2010-03-28        2
#  22  23  물사마귀알로도 불리우며 황색 또는 분홍색의 반투명성 구진(2~3mm 크기)을 가지는...  2010-03-28        2
#  23  24                             기미피부의 손질방법으로 가장 틀린 것은?  2010-03-28        2
#  24  25       장기간에 걸쳐 반복하여 긁거나 비벼서 표피가 건조하고 가죽처럼 두꺼워진 상태는?  2010-03-28        2
#  25  26                   피부의 피지막은 보통 상태에서 어떤 유화상태로 존재하는가?  2010-03-28        2
#  26  27                        피부의 각화과정(Keratinization)이란?  2010-03-28        2
#  27  28                                다음 중 수면을 조절하는 호르몬은?  2010-03-28        2
#  28  29                    다음 중 윗몸일으키기를 하였을 때 주로 강해지는 근육은?  2010-03-28        2
#  29  30                                  다음 중 척수신경이 아닌 것은?  2010-03-28        2
#  30  31                              인체의 혈액량은 체중의 약 몇 %인가?  2010-03-28        2
#  31  32   각 소화기관별 분비되는 소화 효소와 소화시킬 수 있는 영양소가 올바르게 짝지어진 것은?  2010-03-28        2
#  32  33                           성장기까지 뼈의 길이 성장을 주도하는 것은?  2010-03-28        2
#  33  34       난자를 형성하는 성선인 동시에, 에스트로겐과 프로게스테론을 분비하는 재분비선은?  2010-03-28        2
#  34  35                         용액 내에서 이온화 되어 전도체가 되는 물질은?  2010-03-28        2
#  35  36                                  전류의 세기를 측정하는 단위는?  2010-03-28        2
#  36  37                                엔더몰로지 사용방법으로 틀린 것은?  2010-03-28        2
#  37  38                          자외선램프의 사용에 대한 내용으로 틀린 것은?  2010-03-28        2
#  38  39                           고주파기의 효과에 대한 설명으로 틀린 것은?  2010-03-28        2
#  39  40                                 프리마톨을 가장 잘 설명한 것은?  2010-03-28        2
#  40  41                                기능성 화장품에 속하지 않는 것은?  2010-03-28        2
#  41  42                             아로마 오일에 대한 설명 중 틀린 것은?  2010-03-28        2
#  42  43              페이셜 스크럽(facial scrub)에 관한 설명 중 옳은 것은?  2010-03-28        2
#  43  44                                 비누에 대한 설명으로 틀린 것은?  2010-03-28        2
#  44  45                            화장품 성분 중에서 양모에서 정제한 것은?  2010-03-28        2
#  45  46         세정용 화장수의 일종으로 가벼운 화장의 제거에 사용하기에 가장 적합한 것은?  2010-03-28        2
#  46  47                       화장품의 4대 품질 조건에 대한 설명이 틀린 것은?  2010-03-28        2
#  47  48         식품의 혐기성 상태에서 발육하여 신경독소를 분비하는 세균성 식중독 원인균은?  2010-03-28        2
#  48  49                               사회보장의 분류에 속하지 않는 것은?  2010-03-28        2
#  49  50         전염병 신고와 보고규정에서 7일 이내에 관할 보건소에 신고해야 할 전염병은?  2010-03-28        2
#  50  51                         임신 7개월(28주)까지의 분만을 뜻하는 것은?  2010-03-28        2
#  51  52              환자 접촉자가 손의 소독 시 사용하는 약품으로 가장 부적당한 것은?  2010-03-28        2
#  52  53     당이나 혈청과 같이 열에 의해 변성되거나 불안정한 액체의 멸균에 이용되는 소독법은?  2010-03-28        2
#  53  54                             다음 중 화학적 소독법에 해당되는 것은?  2010-03-28        2
#  54  55  석탄산의 희석배수 90배를 기준으로 할 때 어떤 소독약의 석탄산 계수가 4 이었다면...  2010-03-28        2
#  55  56   손님의 얼굴, 머리, 피부 등을 손질하여 손님의 외모를 아름답게 꾸미는 공중위생영업은?  2010-03-28        2
#  56  57  영업소의 폐쇄명령을 받고도 계속하여 영업을 하는 때에 관계공무원으로 하여금 영업소를...  2010-03-28        2
#  57  58              위생교육을 받지 아니한 때에 대한 3차 위반 시행 정지처분 기준은?  2010-03-28        2
#  58  59  공중 이용시설의 위생관리 규정을 위반한 시설의 소유자에게 개선명령을 할 때 명시하여...  2010-03-28        2
#  59  60                      이·미용사의 면허증을 재교부 신청할 수 없는 경우는?  2010-03-28        2,
#      no                                            content     made_at  license
#  0    1                            여드름 관리에 효과적인 성분이 아닌 것은?  2010-07-11        2
#  1    2                         매뉴얼 테크닉의 방법에 대한 설명이 옳은 것은?  2010-07-11        2
#  2    3    딥클렌징(deep cleansing)시 사용되는 제품의 형태와 가장 거리가 먼 것은?  2010-07-11        2
#  3    4                       크림타입의 클렌징 제품에 대한 설명으로 옳은 것은?  2010-07-11        2
#  4    5                                          온습포의 효과는?  2010-07-11        2
#  5    6  유분이 많은 화장품보다는 수분공급에 효과적인 화장품을 선택하여 사용하고, 알코올 함...  2010-07-11        2
#  6    7                             제모의 방법에 대한 내용 중 틀린 것은?  2010-07-11        2
#  7    8                    매뉴얼 테크닉 시 피부미용사의 자세로 가장 적합한 것은?  2010-07-11        2
#  8    9                             각 피부유형에 대한 설명으로 틀린 것은?  2010-07-11        2
#  9   10                             콜라겐 벨벳마스크의 설명으로 틀린 것은?  2010-07-11        2
#  10  11                               피부미용의 기능적 영역이 아닌 것은?  2010-07-11        2
#  11  12  두 가지 이상의 다른 종류의 마스크를 적용시킬 경우 가장 먼저 적용시켜야 하는 마스크는?  2010-07-11        2
#  12  13                       다음 설명에 따르는 화장품이 가장 적합한 피부형은?  2010-07-11        2
#  13  14                           딥클렌징에 대한 내용으로 가장 적합한 것은?  2010-07-11        2
#  14  15                                  피부 미용의 영역이 아닌 것은?  2010-07-11        2
#  15  16                      매뉴얼 테크닉의 부정용 대상과 가장 거리가 먼 것은?  2010-07-11        2
#  16  17                   올바른 피부 관리를 위한 필수조건과 가장 거리가 먼 것은?  2010-07-11        2
#  17  18                       안면 매뉴얼 테크닉의 효과와 가장 거리가 먼 것은?  2010-07-11        2
#  18  19                      피부가 느끼는 오감 중에서 가장 감각이 둔감한 것은?  2010-07-11        2
#  19  20                          기미가 생기는 원인으로 가장 거리가 먼 것은?  2010-07-11        2
#  20  21                               다음 중 원발진으로만 짝지어진 것은?  2010-07-11        2
#  21  22                           피부의 각질(케라틴)을 만들어 내는 세포는?  2010-07-11        2
#  22  23  모세혈관이 위치하며 콜라겐 조직과 탄력적인 엘라스틴섬유 및 뮤코다당류로 구성이 되어...  2010-07-11        2
#  23  24                        피부색소인 멜라닌을 주로 함유하고 있는 세포층은?  2010-07-11        2
#  24  25  나이아신 부족과 아미노산 중 트립토판 결핍으로 생기는 질병으로써 옥수수를 주식으로 ...  2010-07-11        2
#  25  26  손바닥과 발바닥 등 비교적 피부층이 두터운 부위에 주로 분포되어 있으며 수분침투를 ...  2010-07-11        2
#  26  27                     대상포진(헤르페스)의 특징에 대한 설명으로 옳은 것은?  2010-07-11        2
#  27  28                         다음 중 뇌, 척수를 보호하는 골이 아닌 것은?  2010-07-11        2
#  28  29                            다음 중 혈액응고와 관련이 가장 먼 것은?  2010-07-11        2
#  29  30  평활근은 잡아당기면 쉽게 늘어나서 장력(tension)의 큰 변화 없이 본래 길이의...  2010-07-11        2
#  30  31                            다음 중 세포막의 기능 설명이 틀린 것은?  2010-07-11        2
#  31  32                                  다음 중 소화기관이 아닌 것은?  2010-07-11        2
#  32  33                       다음 중 신장의 신문으로 출입하는 것이 아닌 것은?  2010-07-11        2
#  33  34                                 다음 중 중추신경계가 아닌 것은?  2010-07-11        2
#  34  35                                  열을 이용한 기기가 아닌 것은?  2010-07-11        2
#  35  36                              전기장치에서 퓨즈(fuse)의 역할은?  2010-07-11        2
#  36  37                                  브러싱 기기의 올바른 사용법은?  2010-07-11        2
#  37  38  교류 전류로 신경근육계의 자극이나 전기 진단에 많이 이용되는 감응전류(Faradic...  2010-07-11        2
#  38  39                             피부분석 시 사용하는 기기가 아닌 것은?  2010-07-11        2
#  39  40                 진공흡입기 적용을 금지해야 하는 경우와 가장 거리가 먼 것은?  2010-07-11        2
#  40  41  향수를 뿌린 후 즉시 느껴지는 향수의 첫 느낌으로, 주로 휘발성이 강한 향료들로 이...  2010-07-11        2
#  41  42               다음 설명 중 파운데이션의 일반적이 기능과 가장 거리가 먼 것은?  2010-07-11        2
#  42  43                        다음 중 아래 설명에 적합한 유화형태의 판별법은?  2010-07-11        2
#  43  44                        자외선 차단을 도와주는 화장품 성분이 아닌 것은?  2010-07-11        2
#  44  45                 바디 화장품의 종류와 사용 목적의 연결이 적합하지 않은 것은?  2010-07-11        2
#  45  46                     향장품을 선택할 때에 검토해야 하는 조건이 아닌 것은?  2010-07-11        2
#  46  47                                  바디 샴푸의 성질로 틀린 것은?  2010-07-11        2
#  47  48             이/미용업소에서 전염될 수 있는 트라코마에 대한 설명 중 틀린 것은?  2010-07-11        2
#  48  49                                 다음 중 쥐와 관계없는 전염병은?  2010-07-11        2
#  49  50                                실내의 가장 쾌적한 온도와 습도는?  2010-07-11        2
#  50  51                             보건행정의 특성과 가장 거리가 먼 것은?  2010-07-11        2
#  51  52                   이/미용업 종사자가 손을 씻을 때 많이 사용하는 소독약은?  2010-07-11        2
#  52  53                          다음 중 예방법으로 생균백신을 사용하는 것은?  2010-07-11        2
#  53  54                             인체의 창상용 소독약으로 부적당한 것은?  2010-07-11        2
#  54  55                        다음 소독제 중에서 할로겐계에 속하지 않는 것은?  2010-07-11        2
#  55  56  건전한 영업질서를 위하여 공중위생영업자가 준수하여야 할 사항을 준수하지 아니한 자에...  2010-07-11        2
#  56  57                         이/미용업소 내에서 게시하지 않아도 되는 것은?  2010-07-11        2
#  57  58        이/미용사의 면허를 받지 않은 자가 이/미용의 업무를 하였을 때의 벌칙기준은?  2010-07-11        2
#  58  59  이/미용업영업자가 신고를 하지 아니하고 영업소의 상호를 변경한 때의 1차 위반 행정...  2010-07-11        2
#  59  60                         다음 중 공중위생감시원의 업무범위가 아닌 것은?  2010-07-11        2,
#      no                                            content     made_at  license
#  0    1                   화장수(스킨로션)를 사용하는 목적과 가장 거리가 먼 것은?  2010-10-03        2
#  1    2                          딥클렌징 시술과정에 대한 내용 중 틀린 것은?  2010-10-03        2
#  2    3                  제모 할 때 왁스는 일반적으로 어떻게 바르는 것이 적합한가?  2010-10-03        2
#  3    4                            피부타입에 따른 팩의 사용이 잘못된 것은?  2010-10-03        2
#  4    5                          건성피부의 화장품 사용법으로 옳지 않은 것은?  2010-10-03        2
#  5    6                   다음 중 매뉴얼 테크닉을 적용하는 데 가장 적합한 사람은?  2010-10-03        2
#  6    7                매뉴얼 테크닉 방법 중 두드리기의 효과와 가장 거리가 먼 것은?  2010-10-03        2
#  7    8                         매뉴얼 테크닉에 대한 설명 중 거리가 먼 것은?  2010-10-03        2
#  8    9                               다음 중 온습포의 효과가 아닌 것은?  2010-10-03        2
#  9   10              실핏선 피부(cooper rose)의 특징이라고 볼 수 없는 것은?  2010-10-03        2
#  10  11                          주로 피부관리실에서 사용되고 있는 제모방법은?  2010-10-03        2
#  11  12                          입술화장을 지우는 방법이 틀리게 설명된 것은?  2010-10-03        2
#  12  13                             피부미용 역사에 대한 설명이 틀린 것은?  2010-10-03        2
#  13  14                                딥 클렌징과 관련이 가장 먼 것은?  2010-10-03        2
#  14  15                        다음 중 클렌징의 목적과 가장 관계가 깊은 것은?  2010-10-03        2
#  15  16                               셀룰라이트에 대한 설명이 틀린 것은?  2010-10-03        2
#  16  17       세안 후 이마, 볼 부위가 당기며, 잔주름이 많고 화장이 잘 들뜨는 피부유형은?  2010-10-03        2
#  17  18                            피부 관리에서 팩 사용 효과가 아닌 것은?  2010-10-03        2
#  18  19                          다음 중 피지선이 분포되어 있지 않은 부위는?  2010-10-03        2
#  19  20                                  다음 중 원발진에 속하는 것은?  2010-10-03        2
#  20  21                                손톱, 발톱의 설명으로 틀린 것은?  2010-10-03        2
#  21  22                   피부의 구조 중 콜라겐과 엘라스틴이 자리 잡고 있는 층은?  2010-10-03        2
#  22  23            다음 중 세포 재생이 더 이상 되지 않으며 기름샘과 땀샘이 없는 것은?  2010-10-03        2
#  23  24                          비듬이나 때처럼 박리현상을 일으키는 피부층은?  2010-10-03        2
#  24  25                               다음 중 각질이상에 의한 피부질환은?  2010-10-03        2
#  25  26                        다음 중 전염성 피부질환인 두부 백선의 병원체는?  2010-10-03        2
#  26  27                             다음 중 입모근과 가장 관련 있는 것은?  2010-10-03        2
#  27  28                              성장호르몬에 대한 설명으로 틀린 것은?  2010-10-03        2
#  28  29                                 심장에 대한 설명 중 틀린 것은?  2010-10-03        2
#  29  30  3대 영양소를 소화하는 모든 효소를 가지고 있으며, 인슐린(insulin)과 글루카...  2010-10-03        2
#  30  31                       인체의 골격은 약 몇 개의 뼈(골)로 이루어지는가?  2010-10-03        2
#  31  32                      심장근을 무늬모양과 의지에 따라 분류하면 옳은 것은?  2010-10-03        2
#  32  33  세포내 소기관 중에서 세포내의 호흡생리를 담당하고, 이화작용과 동화작용에 의해 에너...  2010-10-03        2
#  33  34                                신경계에 관한 내용 중 틀린 것은?  2010-10-03        2
#  34  35                    이온토포레시스(inontophoresis)의 주 효과는?  2010-10-03        2
#  35  36                                 고주파 사용 방법으로 옳은 것은?  2010-10-03        2
#  36  37                 직류(Direct current)에 대한 설명으로 옳은 것은?  2010-10-03        2
#  37  38                      우드램프 사용 시 피부에 색소침착을 나타내는 색깔은?  2010-10-03        2
#  38  39                          다음 중 피부 분석을 위한 기기가 아닌 것은?  2010-10-03        2
#  39  40                           모세혈관 확장피부의 안면관리로 적당한 것은?  2010-10-03        2
#  40  41                         화장품의 제형에 따른 특징의 설명이 틀린 것은?  2010-10-03        2
#  41  42  내가 좋아하는 향수를 구입하여 샤워 후 바디에 나만의 향으로 산뜻하고 상쾌함을 유지...  2010-10-03        2
#  42  43  대부분 O/W형 유화타입이며, 오일양이 적어 여름철에 많이 상하고 젊은 연령층이 선...  2010-10-03        2
#  43  44                             보습제가 갖추어야 할 조건이 아닌 것은?  2010-10-03        2
#  44  45  진달래과의 월귤나무의 잎에서 추출한 하이드로퀴논 배당페로 멜라닌 활성을 도와주는 티...  2010-10-03        2
#  45  46  "피부에 대한 자극, 알러지, 독성이 없어야 한다."는 내용은 화장품의 4대 요건 ...  2010-10-03        2
#  46  47                    바디 관리 화장품이 가지는 기능과 가장 거리가 먼 것은?  2010-10-03        2
#  47  48                        다음 중 산업종사자와 직업병의 연결이 틀린 것은?  2010-10-03        2
#  48  49                  다음 중에서 접촉 감염지수(감수성지수)가 가장 높은 질병은?  2010-10-03        2
#  49  50                                 인수공통 전염병에 해당하는 것은?  2010-10-03        2
#  50  51                         매개곤충과 전파하는 전염병의 연결이 틀린 것은?  2010-10-03        2
#  51  52                         다음 중 소독약품의 적정 희석농도가 틀린 것은?  2010-10-03        2
#  52  53  병원성 또는 비병원성 미생물 및 아포를 가진 것을 전부 사멸 또는 제거하는 것을 무...  2010-10-03        2
#  53  54                        결핵환자의 객담 처리방법 중 가장 효과적인 것은?  2010-10-03        2
#  54  55                                    자외선의 작용이 아닌 것은?  2010-10-03        2
#  55  56  광역시 지역에서 이·미용 업소를 운영하는 사람이 영업소의 소재지를 변경하고자 할 때...  2010-10-03        2
#  56  57                       다음 중 이·미용영업에 있어 벌칙기준이 다른 것은?  2010-10-03        2
#  57  58          1회용 면도날을 2인 이상 손님에게 사용한 때의 1차 위반 행정처분기준은?  2010-10-03        2
#  58  59                            이·미용사의 면허를 받을 수 없는 사람은?  2010-10-03        2
#  59  60  면허증 분실로 인해 재교부를 받았을 때, 잃어버린 면허를 찾은 경우 반납하여야 하는...  2010-10-03        2,
#      no                                            content     made_at  license
#  0    1                               딥클렌징에 대한 설명으로 틀린 것은?  2011-02-13        2
#  1    2                        우드램프에 의한 피부의 분석 결과 중 틀린 것은?  2011-02-13        2
#  2    3                         매뉴얼 테크닉 작업 시 주의사항으로 옳은 것은?  2011-02-13        2
#  3    4                             피부타입과 화장품과의 연결이 틀린 것은?  2011-02-13        2
#  4    5  다음 중 당일 적용한 피부관리 내용을 고객카드에 기록하고 자가 관리 방법을 조언하는...  2011-02-13        2
#  5    6                          매뉴얼 테크닉의 효과와 가장 거리가 먼 것은?  2011-02-13        2
#  6    7                             일시적인 제모방법에 해당되지 않는 것은?  2011-02-13        2
#  7    8                                천연팩에 대한 설명 중 틀린 것은?  2011-02-13        2
#  8    9                          클렌징에 대한 설명으로 가장 거리가 먼 것은?  2011-02-13        2
#  9   10                           딥클렌징 관리 시 유의 사항 중 옳은 것은?  2011-02-13        2
#  10  11                    기초화장품의 사용 목적 및 효과와 가장 거리가 먼 것은?  2011-02-13        2
#  11  12  림프드레나지 기법 중 손바닥 전체 또는 엄지손가락을 피부 위에 올려놓고 앞으로 나선...  2011-02-13        2
#  12  13                     제모관리 중 왁싱에 대한 내용과 가장 거리가 먼 것은?  2011-02-13        2
#  13  14                               온열 석고마스크의 효과가 아닌 것은?  2011-02-13        2
#  14  15  신체 각 부위별 매뉴얼 테크닉을 하는 경우 고려해야 할 유의사항과 가장 거리가 먼 것은?  2011-02-13        2
#  15  16                                   피부미용의 목적이 아닌 것은?  2011-02-13        2
#  16  17                      클렌징 과정에서 제일 먼저 클렌징을 해야 할 부위는?  2011-02-13        2
#  17  18                                      피부분석을 하는 목적은?  2011-02-13        2
#  18  19                        다음 중 적외선에 관한 설명으로 옳지 않은 것은?  2011-02-13        2
#  19  20                       다음 중 자외선이 피부에 미치는 영향이 아닌 것은?  2011-02-13        2
#  20  21                     피부에 있어 색소세포가 가장 많이 존재하고 있는 곳은?  2011-02-13        2
#  21  22  우리 피부의 세포가 기저층에서 생성되어 각질세포로 변화하여 피부표면으로부터 떨어져 ...  2011-02-13        2
#  22  23  사춘기 이후에 주로 분비가 되며, 모공을 통하여 분비되어 독특한 체취를 발생시키는 것은?  2011-02-13        2
#  23  24                                피지선에 대한 설명으로 틀린 것은?  2011-02-13        2
#  24  25  체내에 부족하면 괴혈병을 유발시키며, 피부와 잇몸에서 피가 나오게 하고 빈혈을 일으...  2011-02-13        2
#  25  26                                 한선에 대한 설명 중 틀린 것은?  2011-02-13        2
#  26  27                                     피부의 기능이 아닌 것은?  2011-02-13        2
#  27  28                            혈액 중 혈액응고에 주로 관여하는 세포는?  2011-02-13        2
#  28  29                        눈살을 찌푸리고 이마에 주름을 짓게 하는 근육은?  2011-02-13        2
#  29  30     피지의 세포 중 전해질 및 수분대사에 관여하는 영류피질 호르몬을 분비하는 세포군은?  2011-02-13        2
#  30  31                               뇌신경과 척수신경은 각각 몇 쌍인가?  2011-02-13        2
#  31  32                             다음 중 간의 역할에 가장 적합한 것은?  2011-02-13        2
#  32  33                        두개골(skull)을 구성하는 뼈로 알맞은 것은?  2011-02-13        2
#  33  34  물질 이동시 물질을 이루고 있는 입자들이 스스로 운동하여 농도가 높은 곳에서 낮은 ...  2011-02-13        2
#  34  35                                  전류에 대한 설명이 틀린 것은?  2011-02-13        2
#  35  36    미용기기로 사용되는 진공흡입기(vacuum or suction)와 관련이 없는 것은?  2011-02-13        2
#  36  37                                확대경에 대한 설명으로 틀린 것은?  2011-02-13        2
#  37  38  갈바닉 전류의 음극에서 생성되는 알카리를 이용하여 피부 표면의 피지와 모공 속의 노...  2011-02-13        2
#  38  39                                   다음 중 PH의 옳은 설명은?  2011-02-13        2
#  39  40          우드램프 사용 시 지성부위의 코메도(comedo)는 어떤 색으로 보이는가?  2011-02-13        2
#  40  41  손을 대상으로 하는 제품 중 알코올을 주 베이스로 하며, 청결 및 소독을 주된 목적...  2011-02-13        2
#  41  42                              클렌징크림의 설명으로 맞지 않은 것은?  2011-02-13        2
#  42  43                             미백화장품에 사용되는 원료가 아닌 것은?  2011-02-13        2
#  43  44                   다음 중 여드름의 발생 가능성이 가장 적은 화장품 성분은?  2011-02-13        2
#  44  45                                   캐리어오일로서 부적합한 것은?  2011-02-13        2
#  45  46                            다음 중 화장품에 사용되는 주요 방부제는?  2011-02-13        2
#  46  47                     주름개선 기능성 화장품의 효과와 가장 거리가 먼 것은?  2011-02-13        2
#  47  48                              공중보건학의 정의로 가장 적합한 것은?  2011-02-13        2
#  48  49                          성층권의 오존층을 파괴시키는 대표적인 가스는?  2011-02-13        2
#  49  50                              기생충과 중간숙주의 연결이 틀린 것은?  2011-02-13        2
#  50  51                           질병 발생의 3대 요인이 옳게 구성된 것은?  2011-02-13        2
#  51  52                        다음 중 소독에 영향을 가장 적게 미치는 인자는?  2011-02-13        2
#  52  53                       다음 중 넓은 지역의 방역용 소독제로 적당한 것은?  2011-02-13        2
#  53  54  100도씨 이상 고온의 수증기를 고압상태에서 미생물, 포자 등과 접촉시켜 멸균할 수...  2011-02-13        2
#  54  55                      모기를 매개곤충으로 하여 일으키는 질병이 아닌 것은?  2011-02-13        2
#  55  56              이·미용업소에서 손님이 보기 쉬운 곳에 게시하지 않아도 되는 것은?  2011-02-13        2
#  56  57                     이·미용사의 면허를 받기 위한 자격요건으로 틀린 것은?  2011-02-13        2
#  57  58  영업정지처분을 받고 그 영업정지 기간 중 영업을 한때에 대한 1차 위반 시 행정처분...  2011-02-13        2
#  58  59   이·미용사의 면허증을 다른 사람에게 대여한때의 법칙 행정처분 조치 사항으로 옳은 것은?  2011-02-13        2
#  59  60  이·미용사는 영업소 외의 장소에는 이·미용 업무를 할 수 없다. 그러나 특별한 사유...  2011-02-13        2,
#      no                                            content     made_at  license
#  0    1                              클렌징 제품에 대한 설명이 틀린 것은?  2011-04-17        2
#  1    2                            딥 클렌징의 효과와 가장 거리가 먼 것은?  2011-04-17        2
#  2    3                            팩의 제거 방법에 따른 분류가 아닌 것은?  2011-04-17        2
#  3    4                             클렌징 시술에 대한 내용 중 틀린 것은?  2011-04-17        2
#  4    5         피부 분석표 작성시 피부 표면의 혈액순환상태에 따른 분류 표시가 아닌 것은?  2011-04-17        2
#  5    6             신체 각 부위 관리에서 매뉴얼 테크닉의 효과와 가장 거리가 먼 것은?  2011-04-17        2
#  6    7                            화장수의 도포 목적 및 효과로 옳은 것은?  2011-04-17        2
#  7    8                          피부 미용의 역사에 대한 설명 중 옳은 것은?  2011-04-17        2
#  8    9                    다음 중 피부 미용에서의 딥 클렌징에 속하지 않은 것은?  2011-04-17        2
#  9   10                             피부 유형을 결정하는 요인이 아닌 것은?  2011-04-17        2
#  10  11                          매뉴얼 테크닉의 효과와 가장 거리가 먼 것은?  2011-04-17        2
#  11  12                                일시적 제모에 해당하지 않은 것은?  2011-04-17        2
#  12  13                             팩에 대한 내용 중 적합하지 않은 것은?  2011-04-17        2
#  13  14          카르테(고객카드)작성에 반드시 기입되어야 할 사항과 가장 거리가 먼 것은?  2011-04-17        2
#  14  15                          림프 드레니지의 주 대상이 되지 않는 피부는?  2011-04-17        2
#  15  16                    안면관리시 제품의 도포 순서로 가장 바르게 연결된 것은?  2011-04-17        2
#  16  17                   셀룰라이트(cellulite)에 대한 설명 중 틀린 것은?  2011-04-17        2
#  17  18                                 다리 제모의 방법으로 틀린 것은?  2011-04-17        2
#  18  19                               피부의 색소와 관계가 가장 먼 것은?  2011-04-17        2
#  19  20                                다음 중 땀샘의 역할이 아닌 것은?  2011-04-17        2
#  20  21                             피부 각질형성세포의 일반적 각화 주기는?  2011-04-17        2
#  21  22                      콜라겐과 엘라스틴이 주성분으로 이루어진 피부 조직은?  2011-04-17        2
#  22  23                   어부들에게 피부의 노화가 조기에 나타나는 가장 큰 원인은?  2011-04-17        2
#  23  24                                     광노화 현상이 아닌 것은?  2011-04-17        2
#  24  25        피부의 천연보습인자(NMF)의 구성 성분 중 가장 많은 분포를 나타내는 것은?  2011-04-17        2
#  25  26                                 표피에서 촉감을 감지하는 세포는?  2011-04-17        2
#  26  27  우리 몸의 대사 과정에서 배출되는 노폐물, 독소 등이 배설되지 못하고 피부조직에 남...  2011-04-17        2
#  27  28                    담즙을 만들어 포도당을 글리코겐으로 저장하는 소화기관은?  2011-04-17        2
#  28  29                 세포막을 통한 물질이동 방법 중 수동적 방법에 해당하는 것은?  2011-04-17        2
#  29  30                               중추 신경계는 어떻게 구성되어 있나?  2011-04-17        2
#  30  31                          다음 중 배부(back)의 근육이 아닌 것은?  2011-04-17        2
#  31  32                             골격계에 대한 설명 중 옳지 않은 것은?  2011-04-17        2
#  32  33         다리의 혈액순환 이상으로 피부 밑에 형성되는 검푸른 상태를 무엇이라 하는가?  2011-04-17        2
#  33  34  남성의 2차 성장에 영향을 주는 성스테로이드 호르몬으로 두정부 모발의 발육을 억제시...  2011-04-17        2
#  34  35                    고형의 파라핀을 녹이는 파라핀기의 적용범위가 아닌 것은?  2011-04-17        2
#  35  36  컬러테라피의 색상 중 활력, 세포재생, 신경긴장완화, 호르몬대사 조절 효과를 나타내...  2011-04-17        2
#  36  37                     다음 중 전류와 관련된 설명으로 가장 거리가 먼 것은?  2011-04-17        2
#  37  38                          브러시(프리마톨)의 사용 방법으로 틀린 것은?  2011-04-17        2
#  38  39                         피부미용기기의 부적용과 가장 거리가 먼 경우는?  2011-04-17        2
#  39  40                             피부분석 시 사용하는 기기가 아닌 것은?  2011-04-17        2
#  40  41                             다음 중 옳은 것만을 모두 짝지은 것은?  2011-04-17        2
#  41  42                           화장품 제조의 3가지 주요기술이 아닌 것은?  2011-04-17        2
#  42  43                            에센셜 오일을 추출하는 방법이 아닌 것은?  2011-04-17        2
#  43  44                            기능성 화장품류의 주요 효과가 아닌 것은?  2011-04-17        2
#  44  45                            다음 중 향료의 함유량이 가장 적은 것은?  2011-04-17        2
#  45  46                                  팩제의 사용 목적이 아닌 것은?  2011-04-17        2
#  46  47                        화장품에서 요구되는 4대 품질 특성이 아닌 것은?  2011-04-17        2
#  47  48  통조림, 소시지 등 식품의 혐기성 상태에서 발육하여 신경 독소를 분비하여 중독이 되...  2011-04-17        2
#  48  49                           실내 공기의 오명지료로 주로 측정되는 것은?  2011-04-17        2
#  49  50                             관련법 상 제2군에 해당하되는 감염병은?  2011-04-17        2
#  50  51                   예방접종에 있어서 디.피.티(D.P.T)와 무관한 질병은?  2011-04-17        2
#  51  52                             훈증 소독법에 대한 설명 중 틀린 것은?  2011-04-17        2
#  52  53  100% 크레졸 비누액을 환자의 배설물, 토사물, 객담 소독을 위한 소독용 크레졸 ...  2011-04-17        2
#  53  54                               질병 발생의 3대 요소가 아닌 것은?  2011-04-17        2
#  54  55                        화학약품으로 소독시 약품의 구비조건이 아닌 것은?  2011-04-17        2
#  55  56  손님의 얼굴, 머리, 피부 등에 손질을 총하여 손님의 외모를 아름답게 꾸미는 영업에...  2011-04-17        2
#  56  57      변경신고를 하지 아니하고 영업소의 소재지를 변경한 때의 1차 위반 행정처분기준은?  2011-04-17        2
#  57  58              이·미용업소에서 1회용 면도날을 손님 몇 명까지 사용할 수 있는가?  2011-04-17        2
#  58  59                          위생교육은 일 년에 몇 시간을 받아야 하는가?  2011-04-17        2
#  59  60                          다음 중 이·미용업무에 종사할 수 있는 자는?  2011-04-17        2,
#      no                                            content     made_at  license
#  0    1                         매뉴얼 테크닉의 종류 중 기본동작이 아닌 것은?  2011-07-31        2
#  1    2                                팩 사용 시 주의사항이 아닌 것은?  2011-07-31        2
#  2    3                         파우더 타입의 머드팩에 대한 설명이 옳은 것은?  2011-07-31        2
#  3    4                                클렌징 로션에 대한 알맞은 설명은?  2011-07-31        2
#  4    5                        습포의 효과에 대한 내용과 가장 거리가 먼 것은?  2011-07-31        2
#  5    6                      피부상담 시 고려해야할 점으로 가장 거리가 먼 것은?  2011-07-31        2
#  6    7                              매뉴얼테크닉을 적용할 수 있는 경우는?  2011-07-31        2
#  7    8                 신체 각 부위 매뉴얼 테크닉 방법에 대한 내용 중 틀린 것은?  2011-07-31        2
#  8    9                                매뉴얼 테크닉의 효과가 아닌 것은?  2011-07-31        2
#  9   10                          건성피부의 관리방법으로 가장 거리가 먼 것은?  2011-07-31        2
#  10  11                                   피부미용의 영역이 아닌 것은?  2011-07-31        2
#  11  12                                 세안에 대한 설명으로 틀린 것은?  2011-07-31        2
#  12  13                      림프드레니지를 적용할 수 있는 경우에 해당되는 것은?  2011-07-31        2
#  13  14                            피부유형에 맞는 화장품 선택이 아닌 것은?  2011-07-31        2
#  14  15                             딥클렌징의 대상으로 적합하지 않은 것은?  2011-07-31        2
#  15  16                                  제모 시 유의사항이 아닌 것은?  2011-07-31        2
#  16  17  수요법(water therapy, hydrotherapy) 시 지켜야 할 수칙이 아...  2011-07-31        2
#  17  18                            다음 중 물리적인 딥 클렌징이 아닌 것은?  2011-07-31        2
#  18  19                             건강한 손톱에 대한 설명으로 틀린 것은?  2011-07-31        2
#  19  20                                천연보습인자의 설명으로 틀린 것은?  2011-07-31        2
#  20  21  진피에 함유되어 있는 성분으로 우수한 보습능력을 지니어 피부관리 제품에도 많이 함유...  2011-07-31        2
#  21  22                             피부의 기능에 대한 설명으로 틀린 것은?  2011-07-31        2
#  22  23                     다음 중 피부표면의 PH에 가장 큰 영향을 주는 것은?  2011-07-31        2
#  23  24                            탄수화물에 대한 설명으로 옳지 않은 것은?  2011-07-31        2
#  24  25  원주형의 세포가 단층으로 이어져 있으며 각질 형성세포와 색소형성세포가 존재하는 피부...  2011-07-31        2
#  25  26                          다음 중 표피층에 존재하는 세포가 아닌 것은?  2011-07-31        2
#  26  27                              인체에 있어 피지선이 전혀 없는 곳은?  2011-07-31        2
#  27  28                             골격계의 형태에 따른 분류로 옳은 것은?  2011-07-31        2
#  28  29                       비뇨기계에서 배출기관의 순서를 바르게 표현한 것은?  2011-07-31        2
#  29  30                                    다음 설명 중 틀린 내용은?  2011-07-31        2
#  30  31            폐에서 이산화탄소를 내보내고 산소를 받아들이는 역할을 수행하는 순환은?  2011-07-31        2
#  31  32                               성인의 척수신경은 모두 몇 쌍 인가?  2011-07-31        2
#  32  33                             인체에서 방어 작용에 관여 하는 세포는?  2011-07-31        2
#  33  34                             근육은 어떤 작용으로 움직일 수 있는가?  2011-07-31        2
#  34  35                         스티머 사용 시 주의해야할 사항으로 틀린 것은?  2011-07-31        2
#  35  36                         진공흡입기(suction)의 효과로 틀린 것은?  2011-07-31        2
#  36  37                진동브러시(Frimator) 의 올바른 사용 방법이 아닌 것은?  2011-07-31        2
#  37  38                               우드램프에 대한 설명으로 틀린 것은?  2011-07-31        2
#  38  39                    갈바닉(galvanic) 기기의 음극 효과로 틀린 것은?  2011-07-31        2
#  39  40                        고주파 전류의 주파수(진동수)를 측정하는 단위는?  2011-07-31        2
#  40  41                             캐리어 오일에 대한 설명으로 틀린 것은?  2011-07-31        2
#  41  42                              계면활성제에 대한 설명으로 옳은 것은?  2011-07-31        2
#  42  43                              다음 중 냉각기에 의해 제조된 제품은?  2011-07-31        2
#  43  44                     화장품의 분류와 사용목적, 제품이 일치하지 않는 것은?  2011-07-31        2
#  44  45                                  팩의 분류에 속하지 않는 것은?  2011-07-31        2
#  45  46  색소를 염료(dye)와 안료(pigment)로 구분할 때 그 특징에 대해 잘못 설명...  2011-07-31        2
#  46  47                               기능성 화장품에 해당되지 않는 것은?  2011-07-31        2
#  47  48                          보건행정의 제 원리에 관한 것으로 맞는 것은?  2011-07-31        2
#  48  49                      체온을 유지하는데 영향을 주는 온열인자가 아닌 것은?  2011-07-31        2
#  49  50                                      제 3군 감염병인 것은?  2011-07-31        2
#  50  51                  예방접종 중 세균의 독소를 약독화(순화)하여 사용하는 것은?  2011-07-31        2
#  51  52                 어떤 소독약의 석탄계수가 2.0이라는 것은 무엇을 의미하는가?  2011-07-31        2
#  52  53                            다음 중 소독약의 구비조건으로 틀린 것은?  2011-07-31        2
#  53  54  자비소독 시 살균력을 강하게 하고 금속기자재가 녹스는 것을 방지하기 위하여 첨가하는...  2011-07-31        2
#  54  55  무수알코올(100%)을 사용해서 70%의 알코올 1800 mL를 만드는 방법으로 옳...  2011-07-31        2
#  55  56              공중위생업소의 위생서비스 수준의 평가는 몇 년마다 실시해야 하는가?  2011-07-31        2
#  56  57               이·미용업소의 위생관리 의무를 지키지 아니한 자의 과태료 기준은?  2011-07-31        2
#  57  58                        공중위생업자에게 개선 명령을 명할 수 없는 것은?  2011-07-31        2
#  58  59  영업허가 취소 또는 영업장 폐쇄명령을 받고도 계속하여 이·미용 영업을 하는 경우에 ...  2011-07-31        2
#  59  60                        이·미용사 면허를 받을 수 있는 자가 아닌 것은?  2011-07-31        2,
#      no                                            content     made_at  license
#  0    1       매뉴얼 테크닉의 쓰다듬기(effleurage) 동작에 대한 설명 중 맞는 것은?  2011-10-09        2
#  1    2                                   림프 드레니쥐의 주된 작용은?  2011-10-09        2
#  2    3                            다음 중 일시적 제모에 속하지 않는 것은?  2011-10-09        2
#  3    4                                 클렌징에 대한 설명이 아닌 것은?  2011-10-09        2
#  4    5  짙은 화장을 지우는 클렌징 제품 타입으로 중성과 건성 피부에 적합하며, 사용 후 이...  2011-10-09        2
#  5    6              다음 중 건성 피부에 적용되는 화장품 사용법으로 가장 적합한 것은?  2011-10-09        2
#  6    7                           팩의 목적 및 효과와 가장 거리가 먼 것은?  2011-10-09        2
#  7    8             신체 각 부위별 관리에서 매뉴얼 테크닉의 적용이 적합하지 않은 것은?  2011-10-09        2
#  8    9                 피부 관리를 위한 피부 유형 분석의 시기로 가장 적합한 것은?  2011-10-09        2
#  9   10                            여드름 피부에 관련된 설명으로 틀린 것은?  2011-10-09        2
#  10  11                           매뉴얼 테크닉의 효과에 해당하지 않는 것은?  2011-10-09        2
#  11  12                       웜 왁스를 이용하여 제모 하는 방법으로 옳은 것은?  2011-10-09        2
#  12  13                          마스크의 종류에 따른 사용 목적이 틀린 것은?  2011-10-09        2
#  13  14  우리나라 피부 미용 역사에서 혼례 미용법이 발달하고, 세안을 위한 세제 등 목욕 용...  2011-10-09        2
#  14  15       피부 관리 시 최종 마무리 단계에서 냉타올을 사용하는 이유로 가장 적합한 것은?  2011-10-09        2
#  15  16                         딥클렌징에 대한 설명으로 가장 거리가 먼 것은?  2011-10-09        2
#  16  17                지성 피부의 화장품 적용 목적 및 효과로 가장 거리가 먼 것은?  2011-10-09        2
#  17  18                          효소 필링 제의 사용법으로 가장 적합한 것은?  2011-10-09        2
#  18  19  다음 단면도에서 모발의 색상을 결정짓는 멜라닌 색소를 함유하고 있는 모피질(毛皮質:...  2011-10-09        2
#  19  20                     피부에 존재하는 감각기관 중 가장 많이 분포하는 것은?  2011-10-09        2
#  20  21       피부색상을 결정짓는데 주요한 요인이 되는 멜라닌 색소를 만들어 내는 피부 층은?  2011-10-09        2
#  21  22                        체 조직 구성 영양소에 대한 설명으로 틀린 것은?  2011-10-09        2
#  22  23                             피부의 면역에 관한 설명으로 맞는 것은?  2011-10-09        2
#  23  24                                 땀샘에 대한 설명으로 틀린 것은?  2011-10-09        2
#  24  25                        다음 중 UV-A(장파장 자외선)의 파장 범위는?  2011-10-09        2
#  25  26                                  일반적으로 피부 표면의 pH는?  2011-10-09        2
#  26  27           천연 보습 인자(NMF)의 구성 성분 중 40%를 차지하는 중요 성분은?  2011-10-09        2
#  27  28                            수정과 임신에 대한 설명 중 잘못된 것은?  2011-10-09        2
#  28  29            세포 내 소화 기관으로 노폐물과 이물질을 처리하는 역할을 하는 기관은?  2011-10-09        2
#  29  30  다음 중 다당류인 전분을 2당류인 맥아당이나 덱스트린으로 가수분해하는 역할을 하는 ...  2011-10-09        2
#  30  31                        인체의 3가지 형태의 근육 종류 명이 아닌 것은?  2011-10-09        2
#  31  32                        림프 순환에서 다른 사지와는 다른 경로인 부분은?  2011-10-09        2
#  32  33                          뉴런과 뉴런의 접속 부위를 무엇이라고 하는가?  2011-10-09        2
#  33  34                                    골격계의 기능이 아닌 것은?  2011-10-09        2
#  34  35                    안면 진공 흡입기의 사용 방법으로 가장 거리가 먼 것은?  2011-10-09        2
#  35  36                    지성 피부에 적용되는 작업 방법 중 적절하지 않는 것은?  2011-10-09        2
#  36  37          고주파 피부 미용 기기를 사용하는 방법 중 직접법을 올바르게 설명한 것은?  2011-10-09        2
#  37  38  피부 분석 시 육안으로 보기 힘든 피지, 민감도, 색소 침착, 모공의 크기, 트러블...  2011-10-09        2
#  38  39                       초음파를 이용한 스킨 스크러버의 효과가 아닌 것은?  2011-10-09        2
#  39  40  매우 낮은 전압의 직류를 이용하며, 이온 영동법과 디스인크러스테이션의 두 가지 중요...  2011-10-09        2
#  40  41                                  화장수의 설명 중 잘못된 것은?  2011-10-09        2
#  41  42  아로마테라피(aromatherapy)에 사용되는 에센셜 오일에 대한 설명 중 가장 ...  2011-10-09        2
#  42  43                          아래에서 설명하는 유화기로 가장 적합한 것은?  2011-10-09        2
#  43  44                               화장품 성분 중 무기 안료의 특성은?  2011-10-09        2
#  44  45                 여드름 피부용 화장품에 사용되는 성분과 가장 거리가 먼 것은?  2011-10-09        2
#  45  46                    화장품 법 상 화장품의 정의와 관련한 내용이 아닌 것은?  2011-10-09        2
#  46  47                        기능성 화장품의 표시 및 기재 사항이 아닌 것은?  2011-10-09        2
#  47  48                         감염 병 관리상 그 관리가 가장 어려운 대상은?  2011-10-09        2
#  48  49    수돗물로 사용할 상수의 대표적인 오염 지표는? (단, 심미적 영향 물질은 제외한다.)  2011-10-09        2
#  49  50                   비타민이 결핍되었을 때 발생하는 질병의 연결이 틀린 것은?  2011-10-09        2
#  50  51                  일반적인 미생물의 번식에 가장 중요한 요소로만 나열된 것은?  2011-10-09        2
#  51  52                             소독에 사용되는 약제의 이상적인 조건은?  2011-10-09        2
#  52  53  용품이나 가구 등을 일차적으로 청결하게 세척하는 것은 다음의 소독 방법 중 어디에 ...  2011-10-09        2
#  53  54                          바이러스에 대한 일반적인 설명으로 옳은 것은?  2011-10-09        2
#  54  55                      알코올 소독의 미생물 세포에 대한 주된 작용 기전은?  2011-10-09        2
#  55  56                    이·미용 업소의 위생 관리 기준으로 적합하지 않은 것은?  2011-10-09        2
#  56  57                         청문을 실시하여야 하는 사항과 거리가 먼 것은?  2011-10-09        2
#  57  58          과태료 처분에 불복이 있는 경우 어느 기간 내에 이의를 제기할 수 있는가?  2011-10-09        2
#  58  59     이·미용 업의 상속으로 인한 영업자 지위 승계 시 신고 시 구비 서류가 아닌 것은?  2011-10-09        2
#  59  60                  영업소 폐쇄 명령을 받고도 영업을 계속할 때의 벌칙 기준은?  2011-10-09        2]

# %%
# 삽입할 때 배치 크기 설정 (한 번에 100개씩 삽입)
batch_size = 100

# df_list에 저장된 각 데이터프레임을 Supabase에 삽입
for df in questions_df_list:
    # 데이터프레임을 딕셔너리 리스트로 변환
    data_list = df.to_dict(orient='records')

    # 데이터를 batch_size만큼 나누어서 삽입
    for i in range(0, len(data_list), batch_size):
        batch_data = data_list[i:i + batch_size]

        try:
            # Supabase 테이블에 삽입
            response = supabase.table('questions').insert(batch_data).execute()

            # 오류가 발생했을 때만 출력
            if not response.data:
                print(f"Error inserting batch {i // batch_size + 1}: {response}")
        except Exception as e:
            print(f"Exception occurred during batch {i // batch_size + 1}: {e}")
